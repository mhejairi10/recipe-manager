# %%
import adding_recipe as add_recipe
import pandas as pd
import os 
import random as randint
import random_recipe as rd
import member2 as v
import member3 as srch

# %%
def menu():
    
    while True:
        print("\nRecipe Manager")
        print("1. Add a new recipe")
        print("2. Search by ingredient")
        print("3. View all recipes")
        print("4. Random recipe")
        print("5. Exit")

        choice = input("Choose an option: ")

        if choice == "1":
            add_recipe.new_recipe()

        elif choice == "2":
            ind = input("Enter Ingredient:")
            srch.search(ind)
        elif choice == "3":
            v.view_all()

        elif choice == "4":
            rd.random_select()

        elif choice == "5":
            print("Goodbye!")
            break

        else:
            print("Invalid choice")


menu()
# Out:
# Recipe Manager
# 1. Add a new recipe
# 2. Search by ingredient
# 3. View all recipes
# 4. Random recipe
# 5. Exit
# Choose an option:  3
#                  Recipe_Name  Prep_Time_Min
# 0        Spaghetti Carbonara             15
# 1           Classic Omelette              5
# 2           Chicken Stir Fry             20
# 3            Beef Wellington             60
# 4              Avocado Toast              5
# 5  Homemade Margherita Pizza             45
# 6          French Onion Soup             30
# 7     Chocolate Chip Cookies             15
# 8            Chicken Biryani             40
# 9             Berry Smoothie              5
#
# Recipe Manager
# 1. Add a new recipe
# 2. Search by ingredient
# 3. View all recipes
# 4. Random recipe
# 5. Exit
# Choose an option:  2
# Enter Ingredient: eggs
# Error reading file: 'ingredients'
#
# Recipe Manager
# 1. Add a new recipe
# 2. Search by ingredient
# 3. View all recipes
# 4. Random recipe
# 5. Exit
# Choose an option:  2
# ...
