# %%
# ============================================================
# main.py - Terminal Application
#
# Group Members:
# - Elias Abbas
# - Ali Radhi
# - Mohammed Hejairi
# ============================================================

import recipe_manager as rm
import pandas as pd
from datetime import date

CSV_FILE = "data/recipe.csv"


def add_new_recipe():
    print("\nAdd New Recipe")

    name = input("Recipe Name: ")
    ingredients = input("Ingredients separated by commas: ")
    time = (input("Preparation Time in Minutes: "))
    instructions = input("Cooking Instructions: ")
    difficulty = input("Difficulty (Easy / Medium / Hard): ")
    category = input("Category (Breakfast / Lunch / Dinner / Dessert): ")
    servings = (input("Number of Servings: "))
    rating = (input("Rating from 1 to 5: "))
    cooked = input("Have you cooked it before? (Yes/No/Today): ")


    if not name or not ingredients or not instructions:
        print("Please fill all required fields.")
        return

    if not rm.isValidInputName(name):
        print("Recipe name must contain only letters and spaces.")
        return

    if not rm.isValidInputIngredient(ingredients):
        print("Ingredients must contain only letters separated by commas.")
        return

    if not rm.isValidInputNumber(time):
        print("Time must be a number.")
        return

    if not rm.isValidInputNumber(servings):
        print("Servings must be a number.")
        return

    if not rm.isValidInputNumber(rating) or int(rating) < 1 or int(rating) > 5:
        print("Rating must be a number from 1 to 5.")
        return

    if not rm.isValidDifficulty(difficulty):
        print("Invalid difficulty. Choose Easy, Medium, or Hard.")
        return

    if not rm.isValidCategory(category):
        print("Invalid category. Choose Breakfast, Lunch, Dinner, or Dessert.")
        return

    if not rm.isValidCookedChoice(cooked):
        print("Invalid choice. Choose Yes, No, or Today.")
        return

    if cooked == "Yes":
        cooked_date = input("Enter cooked date (YYYY-MM-DD): ")

        if not rm.isValidDate(cooked_date):
            print("Invalid date. Use this format: YYYY-MM-DD")
            return

    elif cooked == "Today":
        cooked_date = date.today().strftime("%Y-%m-%d")

    else:
        cooked_date = None

    rm.save_recipe(
        name,
        ingredients,
        int(time),
        instructions,
        difficulty,
        category,
        int(servings),
        int(rating),
        cooked_date
    )

    print("Recipe added successfully!")

    
def search_by_ingredient():
    print("\nSearch Recipes by Ingredient")

    ingredient = input("Enter ingredient: ")

    if not rm.isValidInputIngredient(ingredient):
        print("Ingredient must contain only letters or space separated by commas.")
        return
    else:
        results = rm.search(ingredient)

        if not results.empty:
            display(results.style.hide(axis='index'))
        else:
            print("No recipes found.")


def view_all_recipes():
    print("\nAll Recipes")

    results = rm.view_all()

    if results is not None:
        display(results.style.hide(axis='index'))
    else:
        print("Sorry, no recipes found.")


def random_recipe_suggestion():
    print("\nRandom Recipe Suggestion")

    results = rm.random_select()

    if results is not None:
        display(results.style.hide(axis='index'))
    else:
        print("Sorry, no recipes found.")


def generate_shopping_list():
    print("\nGenerate Shopping List")

    try:
        df = pd.read_csv(CSV_FILE)

        print("\nAvailable Recipes:")
        for recipe in df["Recipe"]:
            print("- " + recipe)

        selected = input("\nEnter recipe names separated by commas: ")
        if not rm.isValidInputIngredient(selected):
            print("Ingredients must contain only letters.")
        selected_recipes = [item.strip() for item in selected.split(",")]

        shopping_list = rm.generate_shopping_list(selected_recipes)

        print("\nShopping List:")
        for item in shopping_list:
            print("- " + item)

    except FileNotFoundError:
        print("No recipe file found.")


def cooking_history():
    print("\nCooking History")

    results = rm.view_cooking_history()

    if results is not None:
        print(results.to_string(index=False))
    else:
        print("No cooking history found.")

    print("\nSuggestion")

    suggest = rm.suggest_by_history()

    if suggest is not None and not suggest.empty:
        print(suggest.to_string(index=False))

        recipe_name = suggest["Recipe"].iloc[0]
        choice = input("\nWill you cook this today? (Yes/No): ")

        if choice.lower() == "yes":
            rm.update_cooked_date(recipe_name)
            print("Cooking date updated!")
    else:
        print("No suggestion found.")


def main():
    while True:
        print("\n==============================")
        print("Recipe Manager")
        print("==============================")
        print("1. Add New Recipe")
        print("2. Search by Ingredient")
        print("3. View All Recipes")
        print("4. Random Recipe Suggestion")
        print("5. Generate Shopping List")
        print("6. Cooking History")
        print("7. Exit")

        choice = input("Choose an option: ")

        if choice == "1":
            add_new_recipe()
        elif choice == "2":
            search_by_ingredient()
        elif choice == "3":
            view_all_recipes()
        elif choice == "4":
            random_recipe_suggestion()
        elif choice == "5":
            generate_shopping_list()
        elif choice == "6":
            cooking_history()
        elif choice == "7":
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

# %%
main()
# Out:
# ==============================
# Recipe Manager
# ==============================
# 1. Add New Recipe
# 2. Search by Ingredient
# 3. View All Recipes
# 4. Random Recipe Suggestion
# 5. Generate Shopping List
# 6. Cooking History
# 7. Exit
# Choose an option:  5
# Generate Shopping List
#
# Available Recipes:
# - Spaghetti Carbonara
# - Chicken Tikka Masala
# - Pancake Stack
# - Chocolate Lava Cake
# - Caesar Salad
# - Beef Stir Fry
# - French Toast
# - Beef Wellington
# - Greek Yogurt Bowl
# - Vegetable Lasagna
# - Apple Crisp
# - Chicken Alfredo
# - Guacamole
# - Mushroom Risotto
# - Berry Smoothie
# - Tacos Al Pastor
# - Caprese Salad
# - Chocolate Chip Cookies
# - Lentil Soup
# - Ribeye Steak
# - h
# - eggs
# - hummus
# - feeffefeaf
# - yy
# - dw
# Enter recipe names separated by commas:  Spaghetti Carbonara,
# Ingredients must contain only letters.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 main()
#
# Cell In[3], line 210, in main()
#     206             view_all_recipes()
#     207         elif choice == "4":
#     208             random_recipe_suggestion()
#     209         elif choice == "5":
# --> 210             generate_shopping_list()
#     211         elif choice == "6":
#     212             cooking_history()
#     213         elif choice == "7":
#
# Cell In[3], line 155, in generate_shopping_list()
#     151         print("\nShopping List:")
#     152         for item in shopping_list:
#     153             print("- " + item)
#     154
# --> 155     except FileNotFoundError:
#     156         print("No recipe file found.")
#
# File ~\GA_DSB\labs_project\Project1\recipe-manager\recipe_manager.py:131, in generate_shopping_list(selected_recipes)
#     129 row = df[df["Recipe"] == recipe]
#     130 #Assume we have two Recipe: Pizza we will have error
# --> 131 ingredients = row["Ingredients"].iloc[0].split(",")
#     133 for item in ingredients:
#     134     shopping_list.append(item.strip())
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\pandas\core\indexing.py:1773, in _iLocIndexer._getitem_axis(self, key, axis)
#    1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# -> 1773 self._validate_integer(key, axis)
#    1775 return self.obj._ixs(key, axis=axis)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\pandas\core\indexing.py:1706, in _iLocIndexer._validate_integer(self, key, axis)
#    1704 len_axis = len(self.obj._get_axis(axis))
#    1705 if key >= len_axis or key < -len_axis:
# -> 1706     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
